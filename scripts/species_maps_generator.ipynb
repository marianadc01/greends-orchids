# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import requests
import os
from shapely.geometry import Point

# === Configuration ===
INPUT_CSV = "C:\\Users\\mdcoe\\thesis-orchids\\data\\gbif\\epidendrum\\occurrences\\occurrences_final.csv"
OUTPUT_CSV = "C:\\Users\\mdcoe\\thesis-orchids\\data\\gbif\\epidendrum\\occurrences\\occurrences_flagged.csv"
MAPS_FOLDER = "C:\\Users\\mdcoe\\thesis-orchids\\data\\gbif\\epidendrum\\species_maps"
WORLD_SHP = "C:\\Users\\mdcoe\\thesis-orchids\\data\\scripts\\ne_110m_admin_0_countries\\ne_110m_admin_0_countries.shp" 

# Create maps folder if needed
os.makedirs(MAPS_FOLDER, exist_ok=True)

# === Load occurrence data ===
df = pd.read_csv(INPUT_CSV)
df = df.dropna(subset=['decimalLatitude', 'decimalLongitude', 'species', 'country'])

# === Function to get known countries from GBIF ===
def get_gbif_countries(species_name):
    url = f"https://api.gbif.org/v1/occurrence/search"
    params = {
        "scientificName": species_name,
        "limit": 0,
        "facet": "country",
        "facetLimit": 200
    }
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        data = response.json()
        countries = [f['name'] for f in data.get('facets', [])[0].get('counts', [])]
        return set(countries)
    except Exception as e:
        print(f"❌ Error fetching GBIF data for {species_name}: {e}")
        return set()

# === Flag suspicious records ===
def flag_suspicious_records(df):
    flagged = []
    species_list = df['species'].dropna().unique()
    species_country_map = {}

    for species in species_list:
        print(f"\n🔎 Checking species: {species}")
        known_countries = get_gbif_countries(species)
        species_country_map[species] = known_countries
        df_species = df[df['species'] == species]
        
        for idx, row in df_species.iterrows():
            country = row['country']
            basis = str(row.get('basisOfRecord', '')).lower()
            is_suspicious = False
            reason = ''

            if known_countries and country not in known_countries:
                is_suspicious = True
                if 'preserved specimen' in basis:
                    reason = 'Outside known range (Preserved Specimen)'
                else:
                    reason = 'Outside known range'
            
            flagged.append((idx, is_suspicious, reason))

        print(f"✅ Flagged {sum(df_species['country'].isin(known_countries) == False)} suspicious occurrences")

    # Apply flags
    for idx, flag, reason in flagged:
        df.loc[idx, 'suspicious'] = flag
        df.loc[idx, 'suspicious_reason'] = reason

    return df, species_country_map

# === Generate maps per species ===
def generate_species_maps(df, species_country_map):
    world = gpd.read_file(WORLD_SHP)

    for species, known_countries in species_country_map.items():
        df_sp = df[df['species'] == species]
        if df_sp.empty:
            print(f"⚠️ No occurrences found for {species} — skipping.")
            continue

        gdf = gpd.GeoDataFrame(
            df_sp,
            geometry=gpd.points_from_xy(df_sp.decimalLongitude, df_sp.decimalLatitude),
            crs="EPSG:4326"
        )
        suspicious_gdf = gdf[gdf['suspicious'] == True]

        fig, ax = plt.subplots(figsize=(12, 8))
        base = world.plot(ax=ax, color='lightgrey', edgecolor='black')

        # Plot GBIF known countries
        if known_countries:
            country_shapes = world[world['ADMIN'].isin(known_countries)]
            if not country_shapes.empty:
                country_shapes.plot(ax=base, color='lightgreen', alpha=0.5, label='GBIF Known Range')

        # Plot all records
        gdf.plot(ax=base, color='blue', markersize=10, label='All Occurrences')

        # Highlight suspicious
        if not suspicious_gdf.empty:
            suspicious_gdf.plot(ax=base, color='red', markersize=20, label='Suspicious')

        ax.set_title(f'{species} – Occurrences and Known Range')
        ax.axis('off')
        plt.legend()
        plt.tight_layout()

        map_path = os.path.join(MAPS_FOLDER, f"{species.replace(' ', '_')}.png")
        plt.savefig(map_path, dpi=300)
        plt.close()
        print(f"🗺️ Map saved: {map_path}")

# === Run full pipeline ===
if __name__ == "__main__":
    df_flagged, species_country_map = flag_suspicious_records(df)
    df_flagged.to_csv(OUTPUT_CSV, index=False)
    generate_species_maps(df_flagged, species_country_map)
    print(f"\n✅ Done! Output saved to:\n- CSV: {OUTPUT_CSV}\n- Maps: {MAPS_FOLDER}/")
# Out:
# 🔎 Checking species: Epidendrum pseudavicula
# ✅ Flagged 19 suspicious occurrences
#
# 🔎 Checking species: Epidendrum rigidum
# ✅ Flagged 1049 suspicious occurrences
#
# 🔎 Checking species: Epidendrum durum
# ✅ Flagged 37 suspicious occurrences
#
# 🔎 Checking species: Epidendrum secundum
# ✅ Flagged 1762 suspicious occurrences
#
# 🔎 Checking species: Epidendrum vesicatum
# ✅ Flagged 45 suspicious occurrences
#
# 🔎 Checking species: Epidendrum dipus
# ✅ Flagged 8 suspicious occurrences
#
# 🔎 Checking species: Epidendrum caldense
# ✅ Flagged 15 suspicious occurrences
#
# 🔎 Checking species: Epidendrum loefgrenii
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum densiflorum
# ✅ Flagged 159 suspicious occurrences
#
# 🔎 Checking species: Epidendrum strobiliferum
# ✅ Flagged 357 suspicious occurrences
#
# 🔎 Checking species: Epidendrum erectum
# ✅ Flagged 8 suspicious occurrences
#
# 🔎 Checking species: Epidendrum megaloclinium
# ✅ Flagged 13 suspicious occurrences
#
# 🔎 Checking species: Epidendrum ibaguense
# ✅ Flagged 291 suspicious occurrences
#
# 🔎 Checking species: Epidendrum tridactylum
# ✅ Flagged 57 suspicious occurrences
#
# 🔎 Checking species: Epidendrum henschenii
# ✅ Flagged 12 suspicious occurrences
#
# 🔎 Checking species: Epidendrum jamiesonis
# ✅ Flagged 449 suspicious occurrences
#
# 🔎 Checking species: Epidendrum tridens
# ✅ Flagged 52 suspicious occurrences
#
# 🔎 Checking species: Epidendrum barbae
# ✅ Flagged 38 suspicious occurrences
#
# 🔎 Checking species: Epidendrum polyanthum
# ✅ Flagged 217 suspicious occurrences
#
# 🔎 Checking species: Epidendrum ramosum
# ✅ Flagged 901 suspicious occurrences
#
# 🔎 Checking species: Epidendrum paranaense
# ✅ Flagged 84 suspicious occurrences
#
# 🔎 Checking species: Epidendrum cristatum
# ✅ Flagged 166 suspicious occurrences
#
# 🔎 Checking species: Epidendrum armeniacum
# ✅ Flagged 112 suspicious occurrences
#
# 🔎 Checking species: Epidendrum latilabre
# ✅ Flagged 71 suspicious occurrences
#
# 🔎 Checking species: Epidendrum avicula
# ✅ Flagged 125 suspicious occurrences
#
# 🔎 Checking species: Epidendrum nocturnum
# ✅ Flagged 1420 suspicious occurrences
#
# 🔎 Checking species: Epidendrum megagastrium
# ✅ Flagged 11 suspicious occurrences
#
# 🔎 Checking species: Epidendrum cuyujense
# ✅ Flagged 4 suspicious occurrences
#
# 🔎 Checking species: Epidendrum oxyglossum
# ✅ Flagged 20 suspicious occurrences
#
# 🔎 Checking species: Epidendrum sanchoi
# ✅ Flagged 23 suspicious occurrences
#
# 🔎 Checking species: Epidendrum brevivenium
# ✅ Flagged 24 suspicious occurrences
#
# 🔎 Checking species: Epidendrum spathatum
# ✅ Flagged 90 suspicious occurrences
#
# 🔎 Checking species: Epidendrum fimbriatum
# ✅ Flagged 1060 suspicious occurrences
#
# 🔎 Checking species: Epidendrum gastropodium
# ✅ Flagged 92 suspicious occurrences
#
# 🔎 Checking species: Epidendrum gratissimum
# ✅ Flagged 34 suspicious occurrences
#
# 🔎 Checking species: Epidendrum cinnabarinum
# ✅ Flagged 325 suspicious occurrences
#
# 🔎 Checking species: Epidendrum andres-johnsonii
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum mojandae
# ✅ Flagged 11 suspicious occurrences
#
# 🔎 Checking species: Epidendrum campestre
# ✅ Flagged 47 suspicious occurrences
#
# 🔎 Checking species: Epidendrum callobotrys
# ✅ Flagged 1 suspicious occurrences
#
# 🔎 Checking species: Epidendrum echinatum
# ✅ Flagged 9 suspicious occurrences
#
# 🔎 Checking species: Epidendrum miserrimum
# ✅ Flagged 72 suspicious occurrences
#
# 🔎 Checking species: Epidendrum centropetalum
# ✅ Flagged 260 suspicious occurrences
#
# 🔎 Checking species: Epidendrum musciferum
# ✅ Flagged 25 suspicious occurrences
#
# 🔎 Checking species: Epidendrum flexuosum
# ✅ Flagged 431 suspicious occurrences
#
# 🔎 Checking species: Epidendrum proligerum
# ✅ Flagged 102 suspicious occurrences
#
# 🔎 Checking species: Epidendrum glossaspis
# ✅ Flagged 7 suspicious occurrences
#
# 🔎 Checking species: Epidendrum nutantirhachis
# ✅ Flagged 27 suspicious occurrences
#
# 🔎 Checking species: Epidendrum trachythece
# ✅ Flagged 60 suspicious occurrences
#
# 🔎 Checking species: Epidendrum blepharistes
# ✅ Flagged 114 suspicious occurrences
#
# 🔎 Checking species: Epidendrum frutex
# ✅ Flagged 239 suspicious occurrences
#
# 🔎 Checking species: Epidendrum pichinchae
# ✅ Flagged 53 suspicious occurrences
#
# 🔎 Checking species: Epidendrum rhizomaniacum
# ✅ Flagged 4 suspicious occurrences
#
# 🔎 Checking species: Epidendrum trianthum
# ✅ Flagged 12 suspicious occurrences
#
# 🔎 Checking species: Epidendrum mesogastropodium
# ✅ Flagged 16 suspicious occurrences
#
# 🔎 Checking species: Epidendrum microglossoides
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum tolimense
# ✅ Flagged 7 suspicious occurrences
#
# 🔎 Checking species: Epidendrum atrorugosum
# ✅ Flagged 9 suspicious occurrences
#
# 🔎 Checking species: Epidendrum anoglossoides
# ✅ Flagged 31 suspicious occurrences
#
# 🔎 Checking species: Epidendrum pachytepalum
# ✅ Flagged 25 suspicious occurrences
#
# 🔎 Checking species: Epidendrum aggregatum
# ✅ Flagged 28 suspicious occurrences
#
# 🔎 Checking species: Epidendrum calanthum
# ✅ Flagged 179 suspicious occurrences
#
# 🔎 Checking species: Epidendrum suavis
# ✅ Flagged 15 suspicious occurrences
#
# 🔎 Checking species: Epidendrum zosterifolium
# ✅ Flagged 4 suspicious occurrences
#
# 🔎 Checking species: Epidendrum denticulatum
# ✅ Flagged 199 suspicious occurrences
#
# 🔎 Checking species: Epidendrum ciliare
# ✅ Flagged 617 suspicious occurrences
#
# 🔎 Checking species: Epidendrum dendrobioides
# ✅ Flagged 271 suspicious occurrences
#
# 🔎 Checking species: Epidendrum eximium
# ✅ Flagged 54 suspicious occurrences
#
# 🔎 Checking species: Epidendrum sodiroi
# ✅ Flagged 42 suspicious occurrences
#
# 🔎 Checking species: Epidendrum geniculatum
# ✅ Flagged 17 suspicious occurrences
#
# 🔎 Checking species: Epidendrum cardiophyllum
# ✅ Flagged 16 suspicious occurrences
#
# 🔎 Checking species: Epidendrum cochlidium
# ✅ Flagged 116 suspicious occurrences
#
# 🔎 Checking species: Epidendrum elegantissimum
# ✅ Flagged 20 suspicious occurrences
#
# 🔎 Checking species: Epidendrum magnoliae
# ✅ Flagged 66 suspicious occurrences
#
# 🔎 Checking species: Epidendrum difforme
# ✅ Flagged 243 suspicious occurrences
#
# 🔎 Checking species: Epidendrum paniculatum
# ✅ Flagged 257 suspicious occurrences
#
# 🔎 Checking species: Epidendrum parkinsonianum
# ✅ Flagged 259 suspicious occurrences
#
# 🔎 Checking species: Epidendrum radicans
# ✅ Flagged 1590 suspicious occurrences
#
# 🔎 Checking species: Epidendrum radioferens
# ✅ Flagged 89 suspicious occurrences
#
# 🔎 Checking species: Epidendrum exasperatum
# ✅ Flagged 220 suspicious occurrences
#
# 🔎 Checking species: Epidendrum chlorops
# ✅ Flagged 36 suspicious occurrences
#
# 🔎 Checking species: Epidendrum verrucosum
# ✅ Flagged 115 suspicious occurrences
#
# 🔎 Checking species: Epidendrum iltisorum
# ✅ Flagged 1 suspicious occurrences
#
# 🔎 Checking species: Epidendrum anceps
# ✅ Flagged 251 suspicious occurrences
#
# 🔎 Checking species: Epidendrum anisatum
# ✅ Flagged 136 suspicious occurrences
#
# 🔎 Checking species: Epidendrum longicaule
# ✅ Flagged 23 suspicious occurrences
#
# 🔎 Checking species: Epidendrum melistagum
# ✅ Flagged 122 suspicious occurrences
#
# 🔎 Checking species: Epidendrum diffusum
# ✅ Flagged 79 suspicious occurrences
#
# 🔎 Checking species: Epidendrum lignosum
# ✅ Flagged 42 suspicious occurrences
#
# 🔎 Checking species: Epidendrum conopseum
# ✅ Flagged 1159 suspicious occurrences
#
# 🔎 Checking species: Epidendrum mixtum
# ✅ Flagged 124 suspicious occurrences
#
# 🔎 Checking species: Epidendrum clowesii
# ✅ Flagged 28 suspicious occurrences
#
# 🔎 Checking species: Epidendrum bracteolatum
# ✅ Flagged 14 suspicious occurrences
#
# 🔎 Checking species: Epidendrum repens
# ✅ Flagged 176 suspicious occurrences
#
# 🔎 Checking species: Epidendrum fulgens
# ✅ Flagged 437 suspicious occurrences
#
# 🔎 Checking species: Epidendrum stamfordianum
# ✅ Flagged 601 suspicious occurrences
#
# 🔎 Checking species: Epidendrum peperomia
# ✅ Flagged 65 suspicious occurrences
#
# 🔎 Checking species: Epidendrum porphyreum
# ✅ Flagged 56 suspicious occurrences
#
# 🔎 Checking species: Epidendrum patens
# ✅ Flagged 37 suspicious occurrences
#
# 🔎 Checking species: Epidendrum zipaquiranum
# ✅ Flagged 218 suspicious occurrences
#
# 🔎 Checking species: Epidendrum ellipticum
# ✅ Flagged 62 suspicious occurrences
#
# 🔎 Checking species: Epidendrum nutans
# ✅ Flagged 16 suspicious occurrences
#
# 🔎 Checking species: Epidendrum microphyllum
# ✅ Flagged 130 suspicious occurrences
#
# 🔎 Checking species: Epidendrum longicolle
# ✅ Flagged 101 suspicious occurrences
#
# 🔎 Checking species: Epidendrum elongatum
# ✅ Flagged 382 suspicious occurrences
#
# 🔎 Checking species: Epidendrum orchidiflorum
# ✅ Flagged 311 suspicious occurrences
#
# 🔎 Checking species: Epidendrum dialychilum
# ✅ Flagged 14 suspicious occurrences
#
# 🔎 Checking species: Epidendrum octomerioides
# ✅ Flagged 47 suspicious occurrences
#
# 🔎 Checking species: Epidendrum prostratum
# ✅ Flagged 15 suspicious occurrences
#
# 🔎 Checking species: Epidendrum acuminatum
# ✅ Flagged 42 suspicious occurrences
#
# 🔎 Checking species: Epidendrum tipuloideum
# ✅ Flagged 17 suspicious occurrences
#
# 🔎 Checking species: Epidendrum klotzscheanum
# ✅ Flagged 65 suspicious occurrences
#
# 🔎 Checking species: Epidendrum carpophorum
# ✅ Flagged 172 suspicious occurrences
#
# 🔎 Checking species: Epidendrum imthurnii
# ✅ Flagged 30 suspicious occurrences
#
# 🔎 Checking species: Epidendrum excisum
# ✅ Flagged 198 suspicious occurrences
#
# 🔎 Checking species: Epidendrum evelynae
# ✅ Flagged 6 suspicious occurrences
#
# 🔎 Checking species: Epidendrum allenii
# ✅ Flagged 15 suspicious occurrences
#
# 🔎 Checking species: Epidendrum megalospathum
# ✅ Flagged 79 suspicious occurrences
#
# 🔎 Checking species: Epidendrum geminiflorum
# ✅ Flagged 148 suspicious occurrences
#
# 🔎 Checking species: Epidendrum norae
# ✅ Flagged 15 suspicious occurrences
#
# 🔎 Checking species: Epidendrum suborbiculare
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum chioneum
# ✅ Flagged 187 suspicious occurrences
#
# 🔎 Checking species: Epidendrum schlimii
# ✅ Flagged 26 suspicious occurrences
#
# 🔎 Checking species: Epidendrum littorale
# ✅ Flagged 18 suspicious occurrences
#
# 🔎 Checking species: Epidendrum calyptratum
# ✅ Flagged 25 suspicious occurrences
#
# 🔎 Checking species: Epidendrum macrocarpum
# ✅ Flagged 111 suspicious occurrences
#
# 🔎 Checking species: Epidendrum funckii
# ✅ Flagged 47 suspicious occurrences
#
# 🔎 Checking species: Epidendrum karstenii
# ✅ Flagged 19 suspicious occurrences
#
# 🔎 Checking species: Epidendrum aura-usecheae
# ✅ Flagged 60 suspicious occurrences
#
# 🔎 Checking species: Epidendrum steyermarkii
# ✅ Flagged 11 suspicious occurrences
#
# 🔎 Checking species: Epidendrum hypoporphyreum
# ✅ Flagged 13 suspicious occurrences
#
# 🔎 Checking species: Epidendrum erosum
# ✅ Flagged 113 suspicious occurrences
#
# 🔎 Checking species: Epidendrum moritzii
# ✅ Flagged 61 suspicious occurrences
#
# 🔎 Checking species: Epidendrum elleanthoides
# ✅ Flagged 82 suspicious occurrences
#
# 🔎 Checking species: Epidendrum scytocladium
# ✅ Flagged 100 suspicious occurrences
#
# 🔎 Checking species: Epidendrum sumapacense
# ✅ Flagged 3 suspicious occurrences
#
# 🔎 Checking species: Epidendrum longiflorum
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum maderoi
# ✅ Flagged 11 suspicious occurrences
#
# 🔎 Checking species: Epidendrum prasinum
# ✅ Flagged 7 suspicious occurrences
#
# 🔎 Checking species: Epidendrum scabrum
# ✅ Flagged 36 suspicious occurrences
#
# 🔎 Checking species: Epidendrum xanthinum
# ✅ Flagged 64 suspicious occurrences
#
# 🔎 Checking species: Epidendrum cylindraceum
# ✅ Flagged 84 suspicious occurrences
#
# 🔎 Checking species: Epidendrum baumannianum
# ✅ Flagged 29 suspicious occurrences
#
# 🔎 Checking species: Epidendrum pastoense
# ✅ Flagged 12 suspicious occurrences
#
# 🔎 Checking species: Epidendrum serpens
# ✅ Flagged 28 suspicious occurrences
#
# 🔎 Checking species: Epidendrum coronatum
# ✅ Flagged 95 suspicious occurrences
#
# 🔎 Checking species: Epidendrum fastigiatum
# ✅ Flagged 7 suspicious occurrences
#
# 🔎 Checking species: Epidendrum muricatoides
# ✅ Flagged 8 suspicious occurrences
#
# 🔎 Checking species: Epidendrum hernandoi
# ✅ Flagged 1 suspicious occurrences
#
# 🔎 Checking species: Epidendrum decurviflorum
# ✅ Flagged 40 suspicious occurrences
#
# 🔎 Checking species: Epidendrum unguiculatum
# ✅ Flagged 60 suspicious occurrences
#
# 🔎 Checking species: Epidendrum lacertinum
# ✅ Flagged 22 suspicious occurrences
#
# 🔎 Checking species: Epidendrum chondrochilum
# ✅ Flagged 148 suspicious occurrences
#
# 🔎 Checking species: Epidendrum kolanowskae
# ✅ Flagged 6 suspicious occurrences
#
# 🔎 Checking species: Epidendrum arevaloi
# ✅ Flagged 43 suspicious occurrences
#
# 🔎 Checking species: Epidendrum purpurascens
# ✅ Flagged 71 suspicious occurrences
#
# 🔎 Checking species: Epidendrum dentiferum
# ✅ Flagged 23 suspicious occurrences
#
# 🔎 Checking species: Epidendrum eugenii
# ✅ Flagged 3 suspicious occurrences
#
# 🔎 Checking species: Epidendrum smithii
# ✅ Flagged 4 suspicious occurrences
#
# 🔎 Checking species: Epidendrum cylindrostachys
# ✅ Flagged 62 suspicious occurrences
#
# 🔎 Checking species: Epidendrum luckei
# ✅ Flagged 16 suspicious occurrences
#
# 🔎 Checking species: Epidendrum pseudomancum
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum phyllocharis
# ✅ Flagged 16 suspicious occurrences
#
# 🔎 Checking species: Epidendrum guanacasense
# ✅ Flagged 9 suspicious occurrences
#
# 🔎 Checking species: Epidendrum lanipes
# ✅ Flagged 100 suspicious occurrences
#
# 🔎 Checking species: Epidendrum nevadense
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum lindae
# ✅ Flagged 14 suspicious occurrences
#
# 🔎 Checking species: Epidendrum coryophorum
# ✅ Flagged 51 suspicious occurrences
#
# 🔎 Checking species: Epidendrum angustissimum
# ✅ Flagged 25 suspicious occurrences
#
# 🔎 Checking species: Epidendrum fusagasugaense
# ✅ Flagged 8 suspicious occurrences
#
# 🔎 Checking species: Epidendrum sculptum
# ✅ Flagged 47 suspicious occurrences
#
# 🔎 Checking species: Epidendrum compressum
# ✅ Flagged 79 suspicious occurrences
#
# 🔎 Checking species: Epidendrum grammipetalostachyum
# ✅ Flagged 5 suspicious occurrences
#
# 🔎 Checking species: Epidendrum oliganthum
# ✅ Flagged 42 suspicious occurrences
#
# 🔎 Checking species: Epidendrum cereiflorum
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum rugulosum
# ✅ Flagged 68 suspicious occurrences
#
# 🔎 Checking species: Epidendrum magnicallosum
# ✅ Flagged 9 suspicious occurrences
#
# 🔎 Checking species: Epidendrum attenuatum
# ✅ Flagged 6 suspicious occurrences
#
# 🔎 Checking species: Epidendrum sisgaense
# ✅ Flagged 14 suspicious occurrences
#
# 🔎 Checking species: Epidendrum laeve
# ✅ Flagged 58 suspicious occurrences
#
# 🔎 Checking species: Epidendrum frigidum
# ✅ Flagged 58 suspicious occurrences
#
# 🔎 Checking species: Epidendrum apaganum
# ✅ Flagged 12 suspicious occurrences
#
# 🔎 Checking species: Epidendrum rigidiflorum
# ✅ Flagged 33 suspicious occurrences
#
# 🔎 Checking species: Epidendrum deltogastropodium
# ✅ Flagged 1 suspicious occurrences
#
# 🔎 Checking species: Epidendrum posadarum
# ✅ Flagged 10 suspicious occurrences
#
# 🔎 Checking species: Epidendrum cornanthera
# ✅ Flagged 12 suspicious occurrences
#
# 🔎 Checking species: Epidendrum humeadorense
# ✅ Flagged 1 suspicious occurrences
#
# 🔎 Checking species: Epidendrum xylostachyum
# ✅ Flagged 13 suspicious occurrences
#
# 🔎 Checking species: Epidendrum leeanum
# ✅ Flagged 9 suspicious occurrences
#
# 🔎 Checking species: Epidendrum torquatum
# ✅ Flagged 22 suspicious occurrences
#
# 🔎 Checking species: Epidendrum macroophorum
# ✅ Flagged 37 suspicious occurrences
#
# 🔎 Checking species: Epidendrum vicentinum
# ✅ Flagged 14 suspicious occurrences
#
# 🔎 Checking species: Epidendrum purum
# ✅ Flagged 23 suspicious occurrences
#
# 🔎 Checking species: Epidendrum soratae
# ✅ Flagged 17 suspicious occurrences
#
# 🔎 Checking species: Epidendrum garayi
# ✅ Flagged 7 suspicious occurrences
#
# 🔎 Checking species: Epidendrum glabrilabium
# ✅ Flagged 1 suspicious occurrences
#
# 🔎 Checking species: Epidendrum leucochilum
# ✅ Flagged 35 suspicious occurrences
#
# 🔎 Checking species: Epidendrum bractiacuminatum
# ✅ Flagged 7 suspicious occurrences
#
# 🔎 Checking species: Epidendrum pachyphyton
# ✅ Flagged 8 suspicious occurrences
#
# 🔎 Checking species: Epidendrum rupestre
# ✅ Flagged 9 suspicious occurrences
#
# 🔎 Checking species: Epidendrum stenostachyum
# ✅ Flagged 1 suspicious occurrences
#
# 🔎 Checking species: Epidendrum colombianum
# ✅ Flagged 33 suspicious occurrences
#
# 🔎 Checking species: Epidendrum jejunum
# ✅ Flagged 21 suspicious occurrences
#
# 🔎 Checking species: Epidendrum longirepens
# ✅ Flagged 4 suspicious occurrences
#
# 🔎 Checking species: Epidendrum sumacostachyum
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum summerhayesii
# ✅ Flagged 19 suspicious occurrences
#
# 🔎 Checking species: Epidendrum oxysepalum
# ✅ Flagged 76 suspicious occurrences
#
# 🔎 Checking species: Epidendrum brachystelestachyum
# ✅ Flagged 5 suspicious occurrences
#
# 🔎 Checking species: Epidendrum fritzianum
# ✅ Flagged 16 suspicious occurrences
#
# 🔎 Checking species: Epidendrum lagenomorphum
# ✅ Flagged 4 suspicious occurrences
#
# 🔎 Checking species: Epidendrum quitensium
# ✅ Flagged 8 suspicious occurrences
#
# 🔎 Checking species: Epidendrum borealistachyum
# ✅ Flagged 26 suspicious occurrences
#
# 🔎 Checking species: Epidendrum cardiostachyum
# ✅ Flagged 5 suspicious occurrences
#
# 🔎 Checking species: Epidendrum boyacaense
# ✅ Flagged 1 suspicious occurrences
#
# 🔎 Checking species: Epidendrum pittieri
# ✅ Flagged 12 suspicious occurrences
#
# 🔎 Checking species: Epidendrum sterrophyllum
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum viviparum
# ✅ Flagged 14 suspicious occurrences
#
# 🔎 Checking species: Epidendrum tamaense
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum diothonaeoides
# ✅ Flagged 32 suspicious occurrences
#
# 🔎 Checking species: Epidendrum ellipsophyllum
# ✅ Flagged 17 suspicious occurrences
#
# 🔎 Checking species: Epidendrum erikae
# ✅ Flagged 9 suspicious occurrences
#
# 🔎 Checking species: Epidendrum alsum
# ✅ Flagged 32 suspicious occurrences
#
# 🔎 Checking species: Epidendrum scutella
# ✅ Flagged 20 suspicious occurrences
#
# 🔎 Checking species: Epidendrum platypetalum
# ✅ Flagged 3 suspicious occurrences
#
# 🔎 Checking species: Epidendrum tigriphyllum
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum calyptratoides
# ✅ Flagged 4 suspicious occurrences
#
# 🔎 Checking species: Epidendrum alexii
# ✅ Flagged 4 suspicious occurrences
#
# 🔎 Checking species: Epidendrum lambeauanum
# ✅ Flagged 8 suspicious occurrences
#
# 🔎 Checking species: Epidendrum curtisii
# ✅ Flagged 11 suspicious occurrences
#
# 🔎 Checking species: Epidendrum siphonosepalum
# ✅ Flagged 6 suspicious occurrences
#
# 🔎 Checking species: Epidendrum aguirrei
# ✅ Flagged 5 suspicious occurrences
#
# 🔎 Checking species: Epidendrum ortizii
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum williamsii
# ✅ Flagged 14 suspicious occurrences
#
# 🔎 Checking species: Epidendrum porquerense
# ✅ Flagged 23 suspicious occurrences
#
# 🔎 Checking species: Epidendrum jajense
# ✅ Flagged 31 suspicious occurrences
#
# 🔎 Checking species: Epidendrum ruizianum
# ✅ Flagged 48 suspicious occurrences
#
# 🔎 Checking species: Epidendrum carmelense
# ✅ Flagged 1 suspicious occurrences
#
# 🔎 Checking species: Epidendrum aristatum
# ✅ Flagged 6 suspicious occurrences
#
# 🔎 Checking species: Epidendrum tequendamae
# ✅ Flagged 5 suspicious occurrences
#
# 🔎 Checking species: Epidendrum sarcodes
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum incomptum
# ✅ Flagged 30 suspicious occurrences
#
# 🔎 Checking species: Epidendrum catillus
# ✅ Flagged 31 suspicious occurrences
#
# 🔎 Checking species: Epidendrum cleefii
# ✅ Flagged 1 suspicious occurrences
#
# 🔎 Checking species: Epidendrum vesicicaule
# ✅ Flagged 18 suspicious occurrences
#
# 🔎 Checking species: Epidendrum peraltum
# ✅ Flagged 6 suspicious occurrences
#
# 🔎 Checking species: Epidendrum lockhartioides
# ✅ Flagged 9 suspicious occurrences
#
# 🔎 Checking species: Epidendrum rodrigoi
# ✅ Flagged 1 suspicious occurrences
#
# 🔎 Checking species: Epidendrum arnoldii
# ✅ Flagged 11 suspicious occurrences
#
# 🔎 Checking species: Epidendrum angaritae
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum brachyglossum
# ✅ Flagged 23 suspicious occurrences
#
# 🔎 Checking species: Epidendrum dendrobii
# ✅ Flagged 19 suspicious occurrences
#
# 🔎 Checking species: Epidendrum lacustre
# ✅ Flagged 185 suspicious occurrences
#
# 🔎 Checking species: Epidendrum dendromacroophorum
# ✅ Flagged 7 suspicious occurrences
#
# 🔎 Checking species: Epidendrum lehmannii
# ✅ Flagged 7 suspicious occurrences
#
# 🔎 Checking species: Epidendrum gentryi
# ✅ Flagged 16 suspicious occurrences
#
# 🔎 Checking species: Epidendrum buenaventurae
# ✅ Flagged 25 suspicious occurrences
#
# 🔎 Checking species: Epidendrum aurigineum
# ✅ Flagged 6 suspicious occurrences
#
# 🔎 Checking species: Epidendrum cancanae
# ✅ Flagged 3 suspicious occurrences
#
# 🔎 Checking species: Epidendrum cernuum
# ✅ Flagged 47 suspicious occurrences
#
# 🔎 Checking species: Epidendrum panamense
# ✅ Flagged 8 suspicious occurrences
#
# 🔎 Checking species: Epidendrum criniferum
# ✅ Flagged 43 suspicious occurrences
#
# 🔎 Checking species: Epidendrum imperator
# ✅ Flagged 5 suspicious occurrences
#
# 🔎 Checking species: Epidendrum yarumalense
# ✅ Flagged 6 suspicious occurrences
#
# 🔎 Checking species: Epidendrum olorteguii
# ✅ Flagged 1 suspicious occurrences
#
# 🔎 Checking species: Epidendrum dayseae
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum propinquum
# ✅ Flagged 187 suspicious occurrences
#
# 🔎 Checking species: Epidendrum dixiorum
# ✅ Flagged 11 suspicious occurrences
#
# 🔎 Checking species: Epidendrum arbuscula
# ✅ Flagged 45 suspicious occurrences
#
# 🔎 Checking species: Epidendrum cnemidophorum
# ✅ Flagged 70 suspicious occurrences
#
# 🔎 Checking species: Epidendrum isomerum
# ✅ Flagged 220 suspicious occurrences
#
# 🔎 Checking species: Epidendrum citrosmum
# ✅ Flagged 25 suspicious occurrences
#
# 🔎 Checking species: Epidendrum chrisii-sharoniae
# ✅ Flagged 4 suspicious occurrences
#
# 🔎 Checking species: Epidendrum oerstedii
# ✅ Flagged 36 suspicious occurrences
#
# 🔎 Checking species: Epidendrum powellii
# ✅ Flagged 17 suspicious occurrences
#
# 🔎 Checking species: Epidendrum warrasii
# ✅ Flagged 36 suspicious occurrences
#
# 🔎 Checking species: Epidendrum saxatile
# ✅ Flagged 101 suspicious occurrences
#
# 🔎 Checking species: Epidendrum fruticosum
# ✅ Flagged 22 suspicious occurrences
#
# 🔎 Checking species: Epidendrum smaragdinum
# ✅ Flagged 34 suspicious occurrences
#
# 🔎 Checking species: Epidendrum martianum
# ✅ Flagged 78 suspicious occurrences
#
# 🔎 Checking species: Epidendrum tumuc-humaciense
# ✅ Flagged 48 suspicious occurrences
#
# 🔎 Checking species: Epidendrum pseudodifforme
# ✅ Flagged 144 suspicious occurrences
#
# 🔎 Checking species: Epidendrum amblostomoides
# ✅ Flagged 17 suspicious occurrences
#
# 🔎 Checking species: Epidendrum epidendroides
# ✅ Flagged 7 suspicious occurrences
#
# 🔎 Checking species: Epidendrum hololeucum
# ✅ Flagged 15 suspicious occurrences
#
# 🔎 Checking species: Epidendrum anatipedium
# ✅ Flagged 10 suspicious occurrences
#
# 🔎 Checking species: Epidendrum flammeum
# ✅ Flagged 32 suspicious occurrences
#
# 🔎 Checking species: Epidendrum paranthicum
# ✅ Flagged 131 suspicious occurrences
#
# 🔎 Checking species: Epidendrum aberrans
# ✅ Flagged 49 suspicious occurrences
#
# 🔎 Checking species: Epidendrum circinatum
# ✅ Flagged 8 suspicious occurrences
#
# 🔎 Checking species: Epidendrum myodes
# ✅ Flagged 47 suspicious occurrences
#
# 🔎 Checking species: Epidendrum vulgoamparoanum
# ✅ Flagged 22 suspicious occurrences
#
# 🔎 Checking species: Epidendrum pumilum
# ✅ Flagged 17 suspicious occurrences
#
# 🔎 Checking species: Epidendrum anastasioi
# ✅ Flagged 7 suspicious occurrences
#
# 🔎 Checking species: Epidendrum piliferum
# ✅ Flagged 49 suspicious occurrences
#
# 🔎 Checking species: Epidendrum rugosum
# ✅ Flagged 20 suspicious occurrences
#
# 🔎 Checking species: Epidendrum allochronum
# ✅ Flagged 3 suspicious occurrences
#
# 🔎 Checking species: Epidendrum paucifolium
# ✅ Flagged 35 suspicious occurrences
#
# 🔎 Checking species: Epidendrum santaclarense
# ✅ Flagged 23 suspicious occurrences
#
# 🔎 Checking species: Epidendrum firmum
# ✅ Flagged 64 suspicious occurrences
#
# 🔎 Checking species: Epidendrum horichii
# ✅ Flagged 13 suspicious occurrences
#
# 🔎 Checking species: Epidendrum insulanum
# ✅ Flagged 9 suspicious occurrences
#
# 🔎 Checking species: Epidendrum cocoense
# ✅ Flagged 26 suspicious occurrences
#
# 🔎 Checking species: Epidendrum chlorocorymbos
# ✅ Flagged 205 suspicious occurrences
#
# 🔎 Checking species: Epidendrum davidsei
# ✅ Flagged 5 suspicious occurrences
#
# 🔎 Checking species: Epidendrum laucheanum
# ✅ Flagged 158 suspicious occurrences
#
# 🔎 Checking species: Epidendrum ramonianum
# ✅ Flagged 26 suspicious occurrences
#
# 🔎 Checking species: Epidendrum anoglossum
# ✅ Flagged 94 suspicious occurrences
#
# 🔎 Checking species: Epidendrum flexicaule
# ✅ Flagged 23 suspicious occurrences
#
# 🔎 Checking species: Epidendrum pseudoramosum
# ✅ Flagged 108 suspicious occurrences
#
# 🔎 Checking species: Epidendrum turialvae
# ✅ Flagged 33 suspicious occurrences
#
# 🔎 Checking species: Epidendrum isthmi
# ✅ Flagged 30 suspicious occurrences
#
# 🔎 Checking species: Epidendrum confertum
# ✅ Flagged 9 suspicious occurrences
#
# 🔎 Checking species: Epidendrum wallisii
# ✅ Flagged 57 suspicious occurrences
#
# 🔎 Checking species: Epidendrum schumannianum
# ✅ Flagged 24 suspicious occurrences
#
# 🔎 Checking species: Epidendrum pansamalae
# ✅ Flagged 58 suspicious occurrences
#
# 🔎 Checking species: Epidendrum cardiophorum
# ✅ Flagged 321 suspicious occurrences
#
# 🔎 Checking species: Epidendrum sigmoideum
# ✅ Flagged 3 suspicious occurrences
#
# 🔎 Checking species: Epidendrum pachyceras
# ✅ Flagged 10 suspicious occurrences
#
# 🔎 Checking species: Epidendrum gibbosum
# ✅ Flagged 17 suspicious occurrences
#
# 🔎 Checking species: Epidendrum acroamparoanum
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum erythrostigma
# ✅ Flagged 10 suspicious occurrences
#
# 🔎 Checking species: Epidendrum intermixtum
# ✅ Flagged 20 suspicious occurrences
#
# 🔎 Checking species: Epidendrum eburneum
# ✅ Flagged 114 suspicious occurrences
#
# 🔎 Checking species: Epidendrum lancilabium
# ✅ Flagged 8 suspicious occurrences
#
# 🔎 Checking species: Epidendrum bisulcatum
# ✅ Flagged 22 suspicious occurrences
#
# 🔎 Checking species: Epidendrum parviexasperatum
# ✅ Flagged 26 suspicious occurrences
#
# 🔎 Checking species: Epidendrum rafael-lucasii
# ✅ Flagged 5 suspicious occurrences
#
# 🔎 Checking species: Epidendrum talamancanum
# ✅ Flagged 21 suspicious occurrences
#
# 🔎 Checking species: Epidendrum notabile
# ✅ Flagged 13 suspicious occurrences
#
# 🔎 Checking species: Epidendrum penneystigma
# ✅ Flagged 8 suspicious occurrences
#
# 🔎 Checking species: Epidendrum coriifolium
# ✅ Flagged 54 suspicious occurrences
#
# 🔎 Checking species: Epidendrum hunterianum
# ✅ Flagged 54 suspicious occurrences
#
# 🔎 Checking species: Epidendrum magnibracteatum
# ✅ Flagged 27 suspicious occurrences
#
# 🔎 Checking species: Epidendrum alfaroi
# ✅ Flagged 24 suspicious occurrences
#
# 🔎 Checking species: Epidendrum lagenocolumna
# ✅ Flagged 81 suspicious occurrences
#
# 🔎 Checking species: Epidendrum cordiforme
# ✅ Flagged 6 suspicious occurrences
#
# 🔎 Checking species: Epidendrum paradisicola
# ✅ Flagged 3 suspicious occurrences
#
# 🔎 Checking species: Epidendrum tetraceros
# ✅ Flagged 16 suspicious occurrences
#
# 🔎 Checking species: Epidendrum pentadactylum
# ✅ Flagged 39 suspicious occurrences
#
# 🔎 Checking species: Epidendrum volutum
# ✅ Flagged 9 suspicious occurrences
#
# 🔎 Checking species: Epidendrum polychlamys
# ✅ Flagged 49 suspicious occurrences
#
# 🔎 Checking species: Epidendrum goniorhachis
# ✅ Flagged 13 suspicious occurrences
#
# 🔎 Checking species: Epidendrum endresii
# ✅ Flagged 70 suspicious occurrences
#
# 🔎 Checking species: Epidendrum stevensii
# ✅ Flagged 13 suspicious occurrences
#
# 🔎 Checking species: Epidendrum wercklei
# ✅ Flagged 20 suspicious occurrences
#
# 🔎 Checking species: Epidendrum microdendron
# ✅ Flagged 28 suspicious occurrences
#
# 🔎 Checking species: Epidendrum paraguastigma
# ✅ Flagged 12 suspicious occurrences
#
# 🔎 Checking species: Epidendrum palmidium
# ✅ Flagged 4 suspicious occurrences
#
# 🔎 Checking species: Epidendrum subnutans
# ✅ Flagged 52 suspicious occurrences
#
# 🔎 Checking species: Epidendrum pallens
# ✅ Flagged 36 suspicious occurrences
#
# 🔎 Checking species: Epidendrum pendens
# ✅ Flagged 3 suspicious occurrences
#
# 🔎 Checking species: Epidendrum elcimeyae
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum pinniferum
# ✅ Flagged 20 suspicious occurrences
#
# 🔎 Checking species: Epidendrum selaginella
# ✅ Flagged 41 suspicious occurrences
#
# 🔎 Checking species: Epidendrum atwoodchlamys
# ✅ Flagged 4 suspicious occurrences
#
# 🔎 Checking species: Epidendrum muscicola
# ✅ Flagged 62 suspicious occurrences
#
# 🔎 Checking species: Epidendrum storkii
# ✅ Flagged 30 suspicious occurrences
#
# 🔎 Checking species: Epidendrum alberti
# ✅ Flagged 11 suspicious occurrences
#
# 🔎 Checking species: Epidendrum pseudepidendrum
# ✅ Flagged 27 suspicious occurrences
#
# 🔎 Checking species: Epidendrum adnatum
# ✅ Flagged 25 suspicious occurrences
#
# 🔎 Checking species: Epidendrum crescentilobium
# ✅ Flagged 6 suspicious occurrences
#
# 🔎 Checking species: Epidendrum microrigidiflorum
# ✅ Flagged 9 suspicious occurrences
#
# 🔎 Checking species: Epidendrum stolidium
# ✅ Flagged 5 suspicious occurrences
#
# 🔎 Checking species: Epidendrum nervosiflorum
# ✅ Flagged 3 suspicious occurrences
#
# 🔎 Checking species: Epidendrum barbeyanum
# ✅ Flagged 45 suspicious occurrences
#
# 🔎 Checking species: Epidendrum hawkesii
# ✅ Flagged 14 suspicious occurrences
#
# 🔎 Checking species: Epidendrum odontochilum
# ✅ Flagged 14 suspicious occurrences
#
# 🔎 Checking species: Epidendrum lankesteri
# ✅ Flagged 41 suspicious occurrences
#
# 🔎 Checking species: Epidendrum synchronum
# ✅ Flagged 1 suspicious occurrences
#
# 🔎 Checking species: Epidendrum schlechterianum
# ✅ Flagged 80 suspicious occurrences
#
# 🔎 Checking species: Epidendrum pergameneum
# ✅ Flagged 19 suspicious occurrences
#
# 🔎 Checking species: Epidendrum longibracteatum
# ✅ Flagged 8 suspicious occurrences
#
# 🔎 Checking species: Epidendrum stangeanum
# ✅ Flagged 36 suspicious occurrences
#
# 🔎 Checking species: Epidendrum mora-retanae
# ✅ Flagged 12 suspicious occurrences
#
# 🔎 Checking species: Epidendrum belloi
# ✅ Flagged 8 suspicious occurrences
#
# 🔎 Checking species: Epidendrum philowercklei
# ✅ Flagged 7 suspicious occurrences
#
# 🔎 Checking species: Epidendrum glumarum
# ✅ Flagged 12 suspicious occurrences
#
# 🔎 Checking species: Epidendrum mirabile
# ✅ Flagged 8 suspicious occurrences
#
# 🔎 Checking species: Epidendrum jimenezii
# ✅ Flagged 1 suspicious occurrences
#
# 🔎 Checking species: Epidendrum bilobatum
# ✅ Flagged 12 suspicious occurrences
#
# 🔎 Checking species: Epidendrum macroclinium
# ✅ Flagged 60 suspicious occurrences
#
# 🔎 Checking species: Epidendrum brenesii
# ✅ Flagged 8 suspicious occurrences
#
# 🔎 Checking species: Epidendrum monophlebium
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum veroscriptum
# ✅ Flagged 191 suspicious occurrences
#
# 🔎 Checking species: Epidendrum haberi
# ✅ Flagged 8 suspicious occurrences
#
# 🔎 Checking species: Epidendrum obliquifolium
# ✅ Flagged 3 suspicious occurrences
#
# 🔎 Checking species: Epidendrum cryptanthum
# ✅ Flagged 9 suspicious occurrences
#
# 🔎 Checking species: Epidendrum candelabrum
# ✅ Flagged 11 suspicious occurrences
#
# 🔎 Checking species: Epidendrum angustilobum
# ✅ Flagged 65 suspicious occurrences
#
# 🔎 Checking species: Epidendrum platystigma
# ✅ Flagged 28 suspicious occurrences
#
# 🔎 Checking species: Epidendrum trialatum
# ✅ Flagged 35 suspicious occurrences
#
# 🔎 Checking species: Epidendrum brachyrepens
# ✅ Flagged 5 suspicious occurrences
#
# 🔎 Checking species: Epidendrum resectum
# ✅ Flagged 8 suspicious occurrences
#
# 🔎 Checking species: Epidendrum crescentilobum
# ✅ Flagged 13 suspicious occurrences
#
# 🔎 Checking species: Epidendrum hameri
# ✅ Flagged 6 suspicious occurrences
#
# 🔎 Checking species: Epidendrum exile
# ✅ Flagged 3 suspicious occurrences
#
# 🔎 Checking species: Epidendrum latilabrum
# ✅ Flagged 69 suspicious occurrences
#
# 🔎 Checking species: Epidendrum robustum
# ✅ Flagged 9 suspicious occurrences
#
# 🔎 Checking species: Epidendrum racemosum
# ✅ Flagged 7 suspicious occurrences
#
# 🔎 Checking species: Epidendrum filicaule
# ✅ Flagged 24 suspicious occurrences
#
# 🔎 Checking species: Epidendrum parahybunense
# ✅ Flagged 20 suspicious occurrences
#
# 🔎 Checking species: Epidendrum cooperianum
# ✅ Flagged 11 suspicious occurrences
#
# 🔎 Checking species: Epidendrum chlorinum
# ✅ Flagged 35 suspicious occurrences
#
# 🔎 Checking species: Epidendrum mantiqueiranum
# ✅ Flagged 4 suspicious occurrences
#
# 🔎 Checking species: Epidendrum garciae
# ✅ Flagged 5 suspicious occurrences
#
# 🔎 Checking species: Epidendrum amapense
# ✅ Flagged 12 suspicious occurrences
#
# 🔎 Checking species: Epidendrum pareciense
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum geminiochraceum
# ✅ Flagged 39 suspicious occurrences
#
# 🔎 Checking species: Epidendrum susannae
# ✅ Flagged 1 suspicious occurrences
#
# 🔎 Checking species: Epidendrum juergensenii
# ✅ Flagged 7 suspicious occurrences
#
# 🔎 Checking species: Epidendrum amphistomum
# ✅ Flagged 398 suspicious occurrences
#
# 🔎 Checking species: Epidendrum polygonatum
# ✅ Flagged 8 suspicious occurrences
#
# 🔎 Checking species: Epidendrum arachnoglossum
# ✅ Flagged 199 suspicious occurrences
#
# 🔎 Checking species: Epidendrum melinanthum
# ✅ Flagged 284 suspicious occurrences
#
# 🔎 Checking species: Epidendrum cardiochilum
# ✅ Flagged 43 suspicious occurrences
#
# 🔎 Checking species: Epidendrum ackermanii
# ✅ Flagged 28 suspicious occurrences
#
# 🔎 Checking species: Epidendrum envigadoense
# ✅ Flagged 20 suspicious occurrences
#
# 🔎 Checking species: Epidendrum macdougallii
# ✅ Flagged 35 suspicious occurrences
#
# 🔎 Checking species: Epidendrum acutilobum
# ✅ Flagged 8 suspicious occurrences
#
# 🔎 Checking species: Epidendrum obrienianum
# ✅ Flagged 20 suspicious occurrences
#
# 🔎 Checking species: Epidendrum nanosimplex
# ✅ Flagged 14 suspicious occurrences
#
# 🔎 Checking species: Epidendrum robinson-galindoi
# ✅ Flagged 1 suspicious occurrences
#
# 🔎 Checking species: Epidendrum miserum
# ✅ Flagged 14 suspicious occurrences
#
# 🔎 Checking species: Epidendrum tortipetalum
# ✅ Flagged 13 suspicious occurrences
#
# 🔎 Checking species: Epidendrum tulcanense
# ✅ Flagged 8 suspicious occurrences
#
# 🔎 Checking species: Epidendrum schistochilum
# ✅ Flagged 60 suspicious occurrences
#
# 🔎 Checking species: Epidendrum moronense
# ✅ Flagged 3 suspicious occurrences
#
# 🔎 Checking species: Epidendrum ardens
# ✅ Flagged 17 suspicious occurrences
#
# 🔎 Checking species: Epidendrum pachycoleum
# ✅ Flagged 3 suspicious occurrences
#
# 🔎 Checking species: Epidendrum pallidiflorum
# ✅ Flagged 11 suspicious occurrences
#
# 🔎 Checking species: Epidendrum cilioccidentale
# ✅ Flagged 35 suspicious occurrences
#
# 🔎 Checking species: Epidendrum syringothyrsus
# ✅ Flagged 45 suspicious occurrences
#
# 🔎 Checking species: Epidendrum densifolium
# ✅ Flagged 13 suspicious occurrences
#
# 🔎 Checking species: Epidendrum pajitense
# ✅ Flagged 9 suspicious occurrences
#
# 🔎 Checking species: Epidendrum martinezii
# ✅ Flagged 27 suspicious occurrences
#
# 🔎 Checking species: Epidendrum filamentosum
# ✅ Flagged 20 suspicious occurrences
#
# 🔎 Checking species: Epidendrum spicatum
# ✅ Flagged 60 suspicious occurrences
#
# 🔎 Checking species: Epidendrum longipetalum
# ✅ Flagged 115 suspicious occurrences
#
# 🔎 Checking species: Epidendrum camposii
# ✅ Flagged 15 suspicious occurrences
#
# 🔎 Checking species: Epidendrum marmoratum
# ✅ Flagged 17 suspicious occurrences
#
# 🔎 Checking species: Epidendrum montispichinchense
# ✅ Flagged 17 suspicious occurrences
#
# 🔎 Checking species: Epidendrum petacaense
# ✅ Flagged 4 suspicious occurrences
#
# 🔎 Checking species: Epidendrum scharfii
# ✅ Flagged 35 suspicious occurrences
#
# 🔎 Checking species: Epidendrum pachyclinium
# ✅ Flagged 13 suspicious occurrences
#
# 🔎 Checking species: Epidendrum ammophilum
# ✅ Flagged 5 suspicious occurrences
#
# 🔎 Checking species: Epidendrum renilabium
# ✅ Flagged 28 suspicious occurrences
#
# 🔎 Checking species: Epidendrum oreonastes
# ✅ Flagged 32 suspicious occurrences
#
# 🔎 Checking species: Epidendrum nanegalense
# ✅ Flagged 31 suspicious occurrences
#
# 🔎 Checking species: Epidendrum erectifolium
# ✅ Flagged 18 suspicious occurrences
#
# 🔎 Checking species: Epidendrum englerianum
# ✅ Flagged 41 suspicious occurrences
#
# 🔎 Checking species: Epidendrum cerinum
# ✅ Flagged 36 suspicious occurrences
#
# 🔎 Checking species: Epidendrum falsigarayi
# ✅ Flagged 5 suspicious occurrences
#
# 🔎 Checking species: Epidendrum caligarium
# ✅ Flagged 14 suspicious occurrences
#
# 🔎 Checking species: Epidendrum floridense
# ✅ Flagged 37 suspicious occurrences
#
# 🔎 Checking species: Epidendrum pterostele
# ✅ Flagged 5 suspicious occurrences
#
# 🔎 Checking species: Epidendrum rhaibogyrum
# ✅ Flagged 4 suspicious occurrences
#
# 🔎 Checking species: Epidendrum cottoniiflorum
# ✅ Flagged 23 suspicious occurrences
#
# 🔎 Checking species: Epidendrum farfanii
# ✅ Flagged 4 suspicious occurrences
#
# 🔎 Checking species: Epidendrum cupreum
# ✅ Flagged 7 suspicious occurrences
#
# 🔎 Checking species: Epidendrum chloe
# ✅ Flagged 44 suspicious occurrences
#
# 🔎 Checking species: Epidendrum mamapachae
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum rhombochilum
# ✅ Flagged 22 suspicious occurrences
#
# 🔎 Checking species: Epidendrum jamaicense
# ✅ Flagged 40 suspicious occurrences
#
# 🔎 Checking species: Epidendrum leopardihamatum
# ✅ Flagged 6 suspicious occurrences
#
# 🔎 Checking species: Epidendrum falcivesicicaule
# ✅ Flagged 15 suspicious occurrences
#
# 🔎 Checking species: Epidendrum jaramilloi
# ✅ Flagged 14 suspicious occurrences
#
# 🔎 Checking species: Epidendrum orthocaule
# ✅ Flagged 24 suspicious occurrences
#
# 🔎 Checking species: Epidendrum bivalve
# ✅ Flagged 3 suspicious occurrences
#
# 🔎 Checking species: Epidendrum escobarianum
# ✅ Flagged 3 suspicious occurrences
#
# 🔎 Checking species: Epidendrum galeottianum
# ✅ Flagged 43 suspicious occurrences
#
# 🔎 Checking species: Epidendrum rosilloi
# ✅ Flagged 17 suspicious occurrences
#
# 🔎 Checking species: Epidendrum nicaraguense
# ✅ Flagged 27 suspicious occurrences
#
# 🔎 Checking species: Epidendrum gransabanense
# ✅ Flagged 9 suspicious occurrences
#
# 🔎 Checking species: Epidendrum brachypodum
# ✅ Flagged 1 suspicious occurrences
#
# 🔎 Checking species: Epidendrum quisayanum
# ✅ Flagged 8 suspicious occurrences
#
# 🔎 Checking species: Epidendrum tropidioides
# ✅ Flagged 11 suspicious occurrences
#
# 🔎 Checking species: Epidendrum pseudospathoides
# ✅ Flagged 3 suspicious occurrences
#
# 🔎 Checking species: Epidendrum piperinum
# ✅ Flagged 9 suspicious occurrences
#
# 🔎 Checking species: Epidendrum montigenum
# ✅ Flagged 10 suspicious occurrences
#
# 🔎 Checking species: Epidendrum lowilliamsii
# ✅ Flagged 11 suspicious occurrences
#
# 🔎 Checking species: Epidendrum eustirum
# ✅ Flagged 35 suspicious occurrences
#
# 🔎 Checking species: Epidendrum ariasii
# ✅ Flagged 4 suspicious occurrences
#
# 🔎 Checking species: Epidendrum platychilum
# ✅ Flagged 11 suspicious occurrences
#
# 🔎 Checking species: Epidendrum falsiloquum
# ✅ Flagged 7 suspicious occurrences
#
# 🔎 Checking species: Epidendrum pseudoschumannianum
# ✅ Flagged 34 suspicious occurrences
#
# 🔎 Checking species: Epidendrum waiandtii
# ✅ Flagged 1 suspicious occurrences
#
# 🔎 Checking species: Epidendrum rhodovandoides
# ✅ Flagged 18 suspicious occurrences
#
# 🔎 Checking species: Epidendrum myrianthum
# ✅ Flagged 38 suspicious occurrences
#
# 🔎 Checking species: Epidendrum hymenodes
# ✅ Flagged 19 suspicious occurrences
#
# 🔎 Checking species: Epidendrum azuayense
# ✅ Flagged 7 suspicious occurrences
#
# 🔎 Checking species: Epidendrum rhodochilum
# ✅ Flagged 7 suspicious occurrences
#
# 🔎 Checking species: Epidendrum tziscaoense
# ✅ Flagged 3 suspicious occurrences
#
# 🔎 Checking species: Epidendrum polyanthostachyum
# ✅ Flagged 6 suspicious occurrences
#
# 🔎 Checking species: Epidendrum portokalium
# ✅ Flagged 13 suspicious occurrences
#
# 🔎 Checking species: Epidendrum diommoides
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum jimburense
# ✅ Flagged 3 suspicious occurrences
#
# 🔎 Checking species: Epidendrum wrightii
# ✅ Flagged 26 suspicious occurrences
#
# 🔎 Checking species: Epidendrum acrobatesii
# ✅ Flagged 3 suspicious occurrences
#
# 🔎 Checking species: Epidendrum iang-rondonii
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum holstii
# ✅ Flagged 8 suspicious occurrences
#
# 🔎 Checking species: Epidendrum retrosepalum
# ✅ Flagged 4 suspicious occurrences
#
# 🔎 Checking species: Epidendrum baryanthum
# ✅ Flagged 1 suspicious occurrences
#
# 🔎 Checking species: Epidendrum trachysepalum
# ✅ Flagged 11 suspicious occurrences
#
# 🔎 Checking species: Epidendrum pastranae
# ✅ Flagged 9 suspicious occurrences
#
# 🔎 Checking species: Epidendrum ferrugineum
# ✅ Flagged 6 suspicious occurrences
#
# 🔎 Checking species: Epidendrum mimopsis
# ✅ Flagged 1 suspicious occurrences
#
# 🔎 Checking species: Epidendrum medinae
# ✅ Flagged 6 suspicious occurrences
#
# 🔎 Checking species: Epidendrum mancum
# ✅ Flagged 43 suspicious occurrences
#
# 🔎 Checking species: Epidendrum pseudogramineum
# ✅ Flagged 9 suspicious occurrences
#
# 🔎 Checking species: Epidendrum hemiscleria
# ✅ Flagged 18 suspicious occurrences
#
# 🔎 Checking species: Epidendrum villahermosaense
# ✅ Flagged 1 suspicious occurrences
#
# 🔎 Checking species: Epidendrum dalessandroi
# ✅ Flagged 7 suspicious occurrences
#
# 🔎 Checking species: Epidendrum falcatum
# ✅ Flagged 23 suspicious occurrences
#
# 🔎 Checking species: Epidendrum cleistocoleum
# ✅ Flagged 30 suspicious occurrences
#
# 🔎 Checking species: Epidendrum batesii
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum pallatangae
# ✅ Flagged 42 suspicious occurrences
#
# 🔎 Checking species: Epidendrum tenuicaule
# ✅ Flagged 21 suspicious occurrences
#
# 🔎 Checking species: Epidendrum uribei
# ✅ Flagged 7 suspicious occurrences
#
# 🔎 Checking species: Epidendrum oxycalyx
# ✅ Flagged 30 suspicious occurrences
#
# 🔎 Checking species: Epidendrum tandapianum
# ✅ Flagged 8 suspicious occurrences
#
# 🔎 Checking species: Epidendrum yojoaense
# ✅ Flagged 4 suspicious occurrences
#
# 🔎 Checking species: Epidendrum vandifolium
# ✅ Flagged 43 suspicious occurrences
#
# 🔎 Checking species: Epidendrum sumacoense
# ✅ Flagged 12 suspicious occurrences
#
# 🔎 Checking species: Epidendrum splendens
# ✅ Flagged 7 suspicious occurrences
#
# 🔎 Checking species: Epidendrum kerryae
# ✅ Flagged 9 suspicious occurrences
#
# 🔎 Checking species: Epidendrum sinac
# ✅ Flagged 3 suspicious occurrences
#
# 🔎 Checking species: Epidendrum boricuarum
# ✅ Flagged 32 suspicious occurrences
#
# 🔎 Checking species: Epidendrum polystachyum
# ✅ Flagged 14 suspicious occurrences
#
# 🔎 Checking species: Epidendrum matudae
# ✅ Flagged 21 suspicious occurrences
#
# 🔎 Checking species: Epidendrum subliberum
# ✅ Flagged 6 suspicious occurrences
#
# 🔎 Checking species: Epidendrum maduroi
# ✅ Flagged 3 suspicious occurrences
#
# 🔎 Checking species: Epidendrum purpureocaule
# ✅ Flagged 4 suspicious occurrences
#
# 🔎 Checking species: Epidendrum arevaloides
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum paniculourubambense
# ✅ Flagged 6 suspicious occurrences
#
# 🔎 Checking species: Epidendrum leimebambense
# ✅ Flagged 6 suspicious occurrences
#
# 🔎 Checking species: Epidendrum nitens
# ✅ Flagged 52 suspicious occurrences
#
# 🔎 Checking species: Epidendrum bogotense
# ✅ Flagged 18 suspicious occurrences
#
# 🔎 Checking species: Epidendrum porpax
# ✅ Flagged 34 suspicious occurrences
#
# 🔎 Checking species: Epidendrum hassleri
# ✅ Flagged 10 suspicious occurrences
#
# 🔎 Checking species: Epidendrum chrysomyristicum
# ✅ Flagged 9 suspicious occurrences
#
# 🔎 Checking species: Epidendrum mutelianum
# ✅ Flagged 23 suspicious occurrences
#
# 🔎 Checking species: Epidendrum jatunsachanum
# ✅ Flagged 5 suspicious occurrences
#
# 🔎 Checking species: Epidendrum leonorae
# ✅ Flagged 5 suspicious occurrences
#
# 🔎 Checking species: Epidendrum kabirii
# ✅ Flagged 4 suspicious occurrences
#
# 🔎 Checking species: Epidendrum cirrhochilum
# ✅ Flagged 15 suspicious occurrences
#
# 🔎 Checking species: Epidendrum examinis
# ✅ Flagged 7 suspicious occurrences
#
# 🔎 Checking species: Epidendrum bispathulatum
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum amplum
# ✅ Flagged 30 suspicious occurrences
#
# 🔎 Checking species: Epidendrum bambusiforme
# ✅ Flagged 9 suspicious occurrences
#
# 🔎 Checking species: Epidendrum carchiense
# ✅ Flagged 9 suspicious occurrences
#
# 🔎 Checking species: Epidendrum portillae
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum lueri
# ✅ Flagged 8 suspicious occurrences
#
# 🔎 Checking species: Epidendrum paniculorugulosum
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum succulentum
# ✅ Flagged 25 suspicious occurrences
#
# 🔎 Checking species: Epidendrum puniceoluteum
# ✅ Flagged 10 suspicious occurrences
#
# 🔎 Checking species: Epidendrum dactylodes
# ✅ Flagged 1 suspicious occurrences
#
# 🔎 Checking species: Epidendrum incapachychilum
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum hexagonum
# ✅ Flagged 8 suspicious occurrences
#
# 🔎 Checking species: Epidendrum pfahlii
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum capricornu
# ✅ Flagged 9 suspicious occurrences
#
# 🔎 Checking species: Epidendrum alvarezdeltoroi
# ✅ Flagged 10 suspicious occurrences
#
# 🔎 Checking species: Epidendrum diphyllum
# ✅ Flagged 1 suspicious occurrences
#
# 🔎 Checking species: Epidendrum psilosepalum
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum rhomboscutellum
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum inornatum
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum atwoodii
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum caroli
# ✅ Flagged 15 suspicious occurrences
#
# 🔎 Checking species: Epidendrum whittenii
# ✅ Flagged 3 suspicious occurrences
#
# 🔎 Checking species: Epidendrum microdiothoneum
# ✅ Flagged 26 suspicious occurrences
#
# 🔎 Checking species: Epidendrum caesaris
# ✅ Flagged 5 suspicious occurrences
#
# 🔎 Checking species: Epidendrum chaparense
# ✅ Flagged 11 suspicious occurrences
#
# 🔎 Checking species: Epidendrum neogaliciensis
# ✅ Flagged 1 suspicious occurrences
#
# 🔎 Checking species: Epidendrum magnificum
# ✅ Flagged 14 suspicious occurrences
#
# 🔎 Checking species: Epidendrum vincentinum
# ✅ Flagged 23 suspicious occurrences
#
# 🔎 Checking species: Epidendrum sonsonense
# ✅ Flagged 4 suspicious occurrences
#
# 🔎 Checking species: Epidendrum morae
# ✅ Flagged 1 suspicious occurrences
#
# 🔎 Checking species: Epidendrum agoyanense
# ✅ Flagged 7 suspicious occurrences
#
# 🔎 Checking species: Epidendrum mocinoi
# ✅ Flagged 6 suspicious occurrences
#
# 🔎 Checking species: Epidendrum ulei
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum cuicochaense
# ✅ Flagged 7 suspicious occurrences
#
# 🔎 Checking species: Epidendrum lavendulum
# ✅ Flagged 5 suspicious occurrences
#
# 🔎 Checking species: Epidendrum subliberhombicum
# ✅ Flagged 3 suspicious occurrences
#
# 🔎 Checking species: Epidendrum hagsateri
# ✅ Flagged 9 suspicious occurrences
#
# 🔎 Checking species: Epidendrum porphyrostachyum
# ✅ Flagged 6 suspicious occurrences
#
# 🔎 Checking species: Epidendrum papallactense
# ✅ Flagged 5 suspicious occurrences
#
# 🔎 Checking species: Epidendrum parviflorum
# ✅ Flagged 40 suspicious occurrences
#
# 🔎 Checking species: Epidendrum violascens
# ✅ Flagged 21 suspicious occurrences
#
# 🔎 Checking species: Epidendrum hardingiae
# ✅ Flagged 8 suspicious occurrences
#
# 🔎 Checking species: Epidendrum madsenii
# ✅ Flagged 7 suspicious occurrences
#
# 🔎 Checking species: Epidendrum schweinfurthianum
# ✅ Flagged 16 suspicious occurrences
#
# 🔎 Checking species: Epidendrum flabellilobatum
# ✅ Flagged 4 suspicious occurrences
#
# 🔎 Checking species: Epidendrum urraoense
# ✅ Flagged 1 suspicious occurrences
#
# 🔎 Checking species: Epidendrum corallinum
# ✅ Flagged 10 suspicious occurrences
#
# 🔎 Checking species: Epidendrum freireanum
# ✅ Flagged 5 suspicious occurrences
#
# 🔎 Checking species: Epidendrum tuxtlense
# ✅ Flagged 7 suspicious occurrences
#
# 🔎 Checking species: Epidendrum rauhii
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum pomecense
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum stanhopeanum
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum amaruense
# ✅ Flagged 13 suspicious occurrences
#
# 🔎 Checking species: Epidendrum ciliipetalum
# ✅ Flagged 1 suspicious occurrences
#
# 🔎 Checking species: Epidendrum microanoglossum
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum cochabambanum
# ✅ Flagged 11 suspicious occurrences
#
# 🔎 Checking species: Epidendrum marsupiale
# ✅ Flagged 56 suspicious occurrences
#
# 🔎 Checking species: Epidendrum kockii
# ✅ Flagged 2 suspicious occurrences
#
# 🔎 Checking species: Epidendrum mininocturnum
# ✅ Flagged 19 suspicious occurrences
#
# 🔎 Checking species: Epidendrum milenae
# ✅ Flagged 5 suspicious occurrences
#
# 🔎 Checking species: Epidendrum angeloglossum
# ✅ Flagged 2 suspicious occurrences
#
# ...
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_megalopentadactylum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_totoroense.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_jose-alvarezii.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_insignificans.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_adsettii.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_alpicolonigrense.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_harlingii.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_tetralobum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_guagra-urcuense.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_renilabioides.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_cartilaginiflorum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_microsecundum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_trachychlaena.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_platystomoides.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_aurantiacum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_lophotropis.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_youngii.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_utyumii.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_schistostemum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_centralense.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_constrictum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_nativitatis.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_curimarcense.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_ampelospathum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_ilinizae.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_bogarinii.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_gymnochlamys.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_yanatilense.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_hesperium.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_polychromum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_nematopetalum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_campos-portoi.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_tungurahuae.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_niveum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_pazii.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_bicirrhatum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_pubiflorum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_anchicayanum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_chronoscriptum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_suturatum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_addae.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_agathosmicum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_sinuosum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_hygrohylephilum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_sertorum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_macarense.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_vigosi.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_trulliforme.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_corymborkiphyllum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_wolfii.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_rocalderianum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_kapuleri.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_amictum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_papillosum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_silvae.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_latifolium.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_laterale.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_obergii.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_rojasii.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_tenuispathum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_saximontanum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_infaustum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_cornicallosum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_andinum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_farallonense.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_lizethae.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_aylacotoglossum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_schmidtchenii.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_misasii.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_vieirae.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_putumayoense.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_macrophysum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_hurtadoi.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_pluriracemosum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_maroniense.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_sinnamaryense.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_cobigoi.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_linearidiforme.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_valcinii.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_mathildae.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_ravetianum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_x-foulquieri.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_queirozianum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_dejeaniae.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_dianae.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_chauvetii.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_cyparisii.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_pelletieri.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_juncifolium.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_guiardianum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_yohanii.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_cryptopateras.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_dentilobum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_pogonochilum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_tachirense.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_magalhaesii.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_sulcatum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_sobralioides.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_tacanaense.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_sanchezii.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_tandapioides.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_artelirioi.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_patentifolium.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_josianae.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_spasmosum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_cirrhohirtzii.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_ornithoglossum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_corymbosum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_macasense.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_thelephorum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_chogoncolonchense.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_bryophilum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_chiguindense.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_santiagense.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_amayense.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_compaccii.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_apicilatum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_itacolomiensis.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_brachyrhodochilum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_nuriense.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_ampelomelanoxeros.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_andrei.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_weerakitianum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_serruliferum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_oligophyllum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_guillermoi.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_sympetalostele.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_hastilabium.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_triloboleptophytum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_macuchiense.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_incomptoides.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_igneum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_laxicaule.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_philippii.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_haenkianum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_pachoi.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_lilacinoides.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_peristerium.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_lamprochilum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_microcapitellatum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_convergens.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_avicule.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_rondoniense.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_dorsocarinatum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_churunense.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_oraion.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_shigenobui.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_sterroanthum.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_neogaliciense.png
# 🗺️ Map saved: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps\Epidendrum_tropinectarium.png
#
# ✅ Done! Output saved to:
# - CSV: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\occurrences\occurrences_flagged.csv
# - Maps: C:\Users\mdcoe\thesis-orchids\data\gbif\epidendrum\species_maps/
